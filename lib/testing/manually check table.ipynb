# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
import os
ROOT = r'C:\\Users\\an_em\\LocalDrive\\Projects\\arvadasermons'
os.chdir(ROOT)

# %%
from lib.load_data import load_data

# %%
df = load_data()
# df = df[~(df['series']=='Bonus Episode')]

cols = ['date', 'year', 'title', 'description', 'title_n_splits', 'series',
       'episode_label', 'speaker']

df[cols].head(10)
# Out:
#          date  year                                              title  \
# 0  2026-04-26  2026  Restored | Step 10 | Sarah O'Connor | Mile Hig...
# 1  2026-04-19  2026  Restored | Step 9 | Becca Knudsen | Mile High ...
# 2  2026-04-12  2026  Restored | Step 8 | Tom White | Mile High Vine...
# 4  2026-04-05  2026  Restored | Step 7 | Jay Pathak | Mile High Vin...
# 5  2026-03-29  2026  Restored | Step 6 | Jay Pathak | Mile High Vin...
# 6  2026-03-22  2026  Restored | Step 4 | Ben Folman | Mile High Vin...
# 7  2026-03-15  2026  Restored | Step 5 | Jay Pathak | Mile High Vin...
# 8  2026-03-08  2026  Restored | Step 3 | Andy Masters | Mile High V...
# 9  2026-03-01  2026  Restored | Step 2: Believe | Jay Pathak | Mile...
# 10 2026-02-27  2026  Restored | Step 1: Admit | Jay Pathak | Mile H...
#
#                                           description  title_n_splits  \
# 0   Restored | Step 10 | Sarah O'Connor | Mile Hig...               4
# ...

# %%
df[df['speaker']=="[not available]"]
# Out:
#           date  year                                              title  \
# 206 2022-04-15  2022     LENT 2022 Daily Devotional: Friday, April 15th
# 207 2022-04-14  2022   LENT 2022 Daily Devotional: Thursday, April 14th
# 208 2022-04-13  2022  LENT 2022 Daily Devotional: Wednesday, April 13th
# 209 2022-04-12  2022    LENT 2022 Daily Devotional: Tuesday, April 12th
# 210 2022-04-11  2022    LENT 2022 Daily Devotional:  Monday, April 11th
# 212 2022-04-08  2022      LENT 2022 Daily Devotional: Friday, April 8th
# 213 2022-04-07  2022    LENT 2022 Daily Devotional: Thursday, April 7th
# 214 2022-04-06  2022   LENT 2022 Daily Devotional: Wednesday, April 6th
# 215 2022-04-05  2022     LENT 2022 Daily Devotional: Tuesday, April 5th
# 216 2022-04-04  2022      LENT 2022 Daily Devotional: Monday, April 4th
# 218 2022-04-01  2022      LENT 2022 Daily Devotional: Friday, April 1st
# 219 2022-03-31  2022   LENT 2022 Daily Devotional: Thursday, March 31st
# ...

# %%
cols = ['date', 'title', 'series',
       'episode_label', 'speaker']
df[cols]
# Out:
#           date                                              title  \
# 0   2026-04-26  Restored | Step 10 | Sarah O'Connor | Mile Hig...
# 1   2026-04-19  Restored | Step 9 | Becca Knudsen | Mile High ...
# 2   2026-04-12  Restored | Step 8 | Tom White | Mile High Vine...
# 4   2026-04-05  Restored | Step 7 | Jay Pathak | Mile High Vin...
# 5   2026-03-29  Restored | Step 6 | Jay Pathak | Mile High Vin...
# 6   2026-03-22  Restored | Step 4 | Ben Folman | Mile High Vin...
# 7   2026-03-15  Restored | Step 5 | Jay Pathak | Mile High Vin...
# 8   2026-03-08  Restored | Step 3 | Andy Masters | Mile High V...
# 9   2026-03-01  Restored | Step 2: Believe | Jay Pathak | Mile...
# 10  2026-02-27  Restored | Step 1: Admit | Jay Pathak | Mile H...
# 11  2026-02-15  Restored | The Path Toward Freedom | Tom White...
# 12  2026-02-08  Set Apart | Consecrated for Mission  | Jay Pat...
# 13  2026-02-01  Set Apart | A Consecrated Church | Jay Pathak ...
# ...
