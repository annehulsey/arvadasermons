# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
ROOT = r'C:\\Users\\an_em\\LocalDrive\\Projects\\arvadasermons'
os.chdir(ROOT)

# %%
from lib.load_data import load_data

# %%
idx = df['series']=='bonus episode'
df[idx]
df[~idx]
# Out:
#           date  year                                              title  \
# 1   2026-04-08  2026                       Bonus Episode | The 12 Steps
# 24  2025-11-07  2025             BONUS EPISODE | The E Word | Jay & Tom
# 36  2025-08-22  2025  BONUS EPISODE | Encountering the Kingdom | Jay...
# 40  2025-08-01  2025                    BONUS EPISODE | Job | Jay & Tom
# 45  2025-07-04  2025  BONUS EPISODE | Where Did They All Go? | Jay a...
#
#                                          episode_page  \
# 1   http://milehighvineyard.libsyn.com/bonus-episo...
# 24  http://milehighvineyard.libsyn.com/bonus_the_e...
# 36  http://milehighvineyard.libsyn.com/bonus-episo...
# 40  http://milehighvineyard.libsyn.com/bonus-episo...
# 45  http://milehighvineyard.libsyn.com/bonus-episo...
#
#                                             audio_url episode_id dest_id  \
# 1   http://traffic.libsyn.com/milehighvineyard/5._...   40774430   94476
# ...

# %%
df = load_data()
df.columns
df
# Out:
# Index(['date', 'year', 'title', 'episode_page', 'audio_url', 'episode_id',
#        'dest_id', 'category', 'description', 'title_n_splits', 'series',
#        'episode_label', 'speaker', 'church'],
#       dtype='object')
#            date  year                                              title  \
# 0    2026-04-12  2026  Restored | Step 8 | Tom White | Mile High Vine...
# 1    2026-04-08  2026                       Bonus Episode | The 12 Steps
# 2    2026-04-05  2026  Restored | Step 7 | Jay Pathak | Mile High Vin...
# 3    2026-03-29  2026  Restored | Step 6 | Jay Pathak | Mile High Vin...
# 4    2026-03-22  2026  Restored | Step 4 | Ben Folman | Mile High Vin...
# ..          ...   ...                                                ...
# 193  2022-06-26  2022  Anchor Week 7: God the Holy Spirit (Lord's Day...
# 194  2022-06-19  2022     Anchor Week 6: God the Son (Lord's Days 11-19)
# 195  2022-06-12  2022  Anchor Week 5: The Trinity & God the Father (L...
# ...

# %%
for n_splits in df['title_n_splits'].unique():
    df[df.title_n_splits==n_splits]
# Out:
#           date  year                                              title  \
# 0   2026-04-12  2026  Restored | Step 8 | Tom White | Mile High Vine...
# 2   2026-04-05  2026  Restored | Step 7 | Jay Pathak | Mile High Vin...
# 3   2026-03-29  2026  Restored | Step 6 | Jay Pathak | Mile High Vin...
# 4   2026-03-22  2026  Restored | Step 4 | Ben Folman | Mile High Vin...
# 5   2026-03-15  2026  Restored | Step 5 | Jay Pathak | Mile High Vin...
# ..         ...   ...                                                ...
# 87  2024-08-11  2024  Family Mess 11 | Genesis 28:10-22 | Jay Pathak...
# 88  2024-08-04  2024  Family Mess 10 | Genesis 26:1-33 | Tom White |...
# 89  2024-07-28  2024  Family Mess 9 | Genesis 23 & 25:1-11 | Jay Pat...
# 90  2024-07-21  2024  Family Mess 8 | Genesis 22:1-19 | Jay Pathak |...
# 99  2024-05-19  2024  Mealtime With Jesus 7 | Enacted Promise | Tom ...
#
#                                          episode_page  \
# ...
